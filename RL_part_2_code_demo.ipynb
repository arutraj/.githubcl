# %% [markdown]
# <a href="https://colab.research.google.com/github/arutraj/.githubcl/blob/main/RL_part_2_code_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install dependencies for LunarLander.
# !apt-get install swig > /dev/null 2>&1
# !pip install gymnasium > /dev/null 2>&1
# !pip install gymnasium[box2d] > /dev/null 2>&1
# !pip install gymnasium[classic-control]
# Out:
# Requirement already satisfied: gymnasium[classic-control] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (2.6.1)

# %%
#@title Import required libraries.

import pandas as pd
import gymnasium as gym
import numpy as np
import random
import seaborn as sns

from IPython import display
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.distributions.categorical import Categorical
from torch.optim import Adam
import numpy as np
from gymnasium.spaces import Discrete, Box

# %%
#@title Build a feedforward neural network.

# Build a feedforward neural network with fully connected layers.
# sizes: Defines network dimensions. For sizes = [8, 32, 3], we have 2 layers in
#        total. The first layer expects input of dimension 8 (excluding batch
#        dimension), and gives 32 dimensional output. The second layer expects
#        input of dimension 32 and gives 3 dimensional output.
# activation: Activation function for all layers except final layer. Should add
#             non linearity. The final layer does not apply any activation.
def mlp(sizes, activation=nn.Tanh):
    layers = []
    for j in range(len(sizes)-1):
        act = activation if j < len(sizes)-2 else nn.Identity
        layers += [nn.Linear(sizes[j], sizes[j+1]), act()]
    return nn.Sequential(*layers)

# %% [markdown]
# ####PolicyGradientTrainer
#   * `self.policy_model`: Neural network with fully connected layers.
#     * Assumes: continuous state space and discrete action space.
#     * Output layer has n_action units.
#   * `train_one_epoch`: Makes one policy gradient update to `self.policy_model`.
#   * `train`: Trains the policy for some epochs.
#     * Calls `train_one_epoch` repeatedly.
#     * Returns trained `self.policy_model` and training statistics.
#   * `eval`: Evaluate the trained policy by acting in the environment using the current policy for one episode.
#     * The episode is visualized.
#     * No gradient update is made.
#
#
# ####Training Stats
# * Episode returns.
# * Episode length.

# %%
#@title PolicyGradientTrainer class.
# Trains a policy using Monte Carlo policy gradient update (REINFORCE).
class PolicyGradientTrainer():
    def __init__(self, env_name: str = 'LunarLander-v2', lr: float = 1e-2,
                 max_eps_length: int = 500, epochs: int = 50, n_steps_per_epoch: int = 5000,
                 hidden_sizes: list[int] = [32], verbose: bool = False):
        # Create the environment.
        self.env = gym.make(env_name, render_mode="rgb_array")
        # Obtain observation (ie state) dimension and action dimension from the environment.
        obs_dim = self.env.observation_space.shape[0]
        n_acts = self.env.action_space.n

        # Create the policy model, composed from fully connected layers expecting
        # input of `obs_dim` and output `n_acts` units.
        self.policy_model = mlp(sizes=[obs_dim] + hidden_sizes + [n_acts])
        # Create gradient descent optimizer for the policy model.
        self.optimizer = Adam(self.policy_model.parameters(), lr=lr)

        # Specify how many experiences we will use to train the policy.
        self.epochs = epochs
        self.n_steps_per_epoch = n_steps_per_epoch
        self.max_eps_length = max_eps_length

        # In verbose mode, trainer will print training stats to screen.
        self.verbose = verbose

    # Returns current policy for `obs`, ie the probability distribution of actions at `obs`: pi(*|obs)
    def get_policy(self, obs):
        logits = self.policy_model(obs)
        return Categorical(logits=logits)

    # Samples action at `obs` according to the current policy. We first compute the probaility
    # distribution of actions using `self.get_policy`, then sample an action from the distribution.
    def get_action(self, obs):
        return self.get_policy(obs).sample().item()

    # Compute loss. The gradient of this loss function is equal to the policy gradient
    # we derived for REINFORCE algorithm, using log probability of actions and their returns,
    # from all timestamps across all trajectories.
    def compute_loss(self, all_obs, all_acts, all_returns):
        all_logps = self.get_policy(all_obs).log_prob(all_acts)
        return -(all_logps * all_returns).mean()

    # Make one policy gradient update.
    def train_one_epoch(self):
        # Accumulate observations, actions and returns at all timestamps for the current epoch.
        epoch_obs = []          # for observations
        epoch_acts = []         # for actions
        epoch_returns = []      # for returns in policy gradient

        # Accumulate episode level information for logging.
        episode_returns = []      # for measuring episode returns
        episode_lens = []         # for measuring episode lengths

        # reset episode-specific variables
        obs, _ = self.env.reset()       # first obs comes from starting distribution
        done = False            # signal from environment that episode is over
        episode_rewards = []            # list for rewards accrued throughout ep

        t = 0

        # collect experience by acting in the environment with current policy
        while True:

            # Save the observation.
            epoch_obs.append(obs.copy())

            # Act in the environment
            act = self.get_action(torch.as_tensor(obs, dtype=torch.float32))
            obs, rew, done, truncated, _ = self.env.step(act)

            # Save action and reward.
            epoch_acts.append(act)
            episode_rewards.append(rew)
            t += 1

            # The episode is over when any of the following condition is reached.
            # (1) environment returned "done": lander landed or crashed.
            # (2) we have collected `self.n_steps_per_epoch` actions for the epoch.
            # (3) the current episode has reached `self. max_eps_length` length.
            if (done or
                len(epoch_obs) > self.n_steps_per_epoch or
                t >=self.max_eps_length):

                # Calculate the cumulative reward for the episode, from time 0 to episode end.
                episode_return = sum(episode_rewards)
                # Calulate the length of the episode.
                episode_len = len(episode_rewards)
                episode_returns.append(episode_return)
                episode_lens.append(episode_len)

                # all timestamps in the episode have the sampe return: episode_return
                epoch_returns += [episode_return] * episode_len

                # reset episode-specific variables
                obs, _ = self.env.reset()
                t = 0
                done, episode_rewards = False, []

                # end experience loop if we have enough of it
                if len(epoch_obs) > self.n_steps_per_epoch:
                    break

        # Take a single policy gradient update step with back propagation.
        self.optimizer.zero_grad()
        epoch_loss = self.compute_loss(all_obs=torch.as_tensor(epoch_obs, dtype=torch.float32),
                                       all_acts=torch.as_tensor(epoch_acts, dtype=torch.int32),
                                       all_returns=torch.as_tensor(epoch_returns, dtype=torch.float32)
                                      )
        epoch_loss.backward()
        self.optimizer.step()

        return epoch_loss, episode_returns, episode_lens

    # Train the policy model and return training statistics.
    def train(self):
        # Initialize dictionary for per epoch training stats.
        train_stats = {'iteration': [],
                       'epoch_loss': [],
                       'episode_returns': [],
                       'episode_lens': []}

        # Trains the policy and accumulate training stats.
        for i in range(self.epochs):
            epoch_loss, episode_rets, episode_lens = self.train_one_epoch()
            if self.verbose:
                print('epoch: %3d \t loss: %.3f \t return: %.3f \t ep_len: %.3f'%
                      (i, epoch_loss, np.mean(episode_rets), np.mean(episode_lens)))
            for episode_ret in episode_rets:
              train_stats['iteration'].append(i)
              train_stats['epoch_loss'].append(float(epoch_loss.detach().numpy()))
              train_stats['episode_returns'].append(episode_ret)
              train_stats['episode_lens'].append(np.mean(episode_lens))
        df_train_stats = pd.DataFrame(data=train_stats)

        return df_train_stats

    # Evaluate the policy model by acting in the environment for one episode.
    def eval(self, render_every: int = 1):
        # Start the episode from environment starting distribution.
        obs, _ = self.env.reset()
        t = 0
        ret = 0

        # Act in the environment with current policy.
        while True:
            # Display the observation at `render_every` intervals.
            if t % render_every == 0:
                display.clear_output(wait=True)
                plt.imshow(self.env.render())
                plt.show()

            # Take action using the current policy.
            act = self.get_action(torch.as_tensor(obs, dtype=torch.float32))
            obs, rew, done, truncated, _ = self.env.step(act)

            t += 1
            ret += rew

            if done or truncated or t > self.max_eps_length:
              break

        print(f'return = {ret}. episode length = {t + 1}')

# %%
#@title Visualize lander behavior under random, untrained policy
untrained = PolicyGradientTrainer(env_name='LunarLander-v2', lr=1e-2, max_eps_length=500, n_steps_per_epoch=5000, epochs=300)
untrained.eval()
# Out:
# return = -217.37286632936886. episode length = 91

# %%
#@title Train the policy
trained = PolicyGradientTrainer(env_name='LunarLander-v2', lr=1e-2, max_eps_length=500, n_steps_per_epoch=5000, epochs=300, verbose=True)
stats = trained.train()
# Out:
# <ipython-input-4-015746879d0b>:106: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   epoch_loss = self.compute_loss(all_obs=torch.as_tensor(epoch_obs, dtype=torch.float32),
# epoch:   0 	 loss: -357.014 	 return: -253.598 	 ep_len: 81.984
# epoch:   1 	 loss: -250.646 	 return: -175.327 	 ep_len: 83.350
# epoch:   2 	 loss: -206.482 	 return: -146.585 	 ep_len: 81.984
# epoch:   3 	 loss: -236.097 	 return: -167.005 	 ep_len: 81.984
# epoch:   4 	 loss: -202.634 	 return: -142.864 	 ep_len: 83.350
# epoch:   5 	 loss: -208.014 	 return: -145.893 	 ep_len: 81.984
# epoch:   6 	 loss: -200.195 	 return: -144.204 	 ep_len: 80.661
# epoch:   7 	 loss: -178.581 	 return: -130.302 	 ep_len: 79.381
# epoch:   8 	 loss: -191.345 	 return: -136.765 	 ep_len: 81.984
# epoch:   9 	 loss: -191.188 	 return: -136.813 	 ep_len: 79.381
# epoch:  10 	 loss: -155.703 	 return: -116.820 	 ep_len: 74.642
# epoch:  11 	 loss: -185.847 	 return: -138.102 	 ep_len: 80.661
# epoch:  12 	 loss: -185.541 	 return: -138.244 	 ep_len: 79.381
# epoch:  13 	 loss: -168.755 	 return: -124.677 	 ep_len: 75.773
# epoch:  14 	 loss: -184.187 	 return: -135.182 	 ep_len: 80.661
# epoch:  15 	 loss: -160.188 	 return: -120.333 	 ep_len: 76.938
# epoch:  16 	 loss: -177.863 	 return: -132.033 	 ep_len: 78.141
# epoch:  17 	 loss: -175.003 	 return: -130.925 	 ep_len: 78.141
# epoch:  18 	 loss: -162.730 	 return: -122.887 	 ep_len: 79.381
# epoch:  19 	 loss: -173.035 	 return: -129.860 	 ep_len: 76.938
# epoch:  20 	 loss: -170.715 	 return: -130.076 	 ep_len: 80.661
# epoch:  21 	 loss: -149.022 	 return: -114.999 	 ep_len: 76.938
# epoch:  22 	 loss: -164.167 	 return: -124.168 	 ep_len: 76.938
# epoch:  23 	 loss: -161.818 	 return: -122.116 	 ep_len: 78.141
# epoch:  24 	 loss: -166.732 	 return: -124.958 	 ep_len: 78.141
# epoch:  25 	 loss: -179.595 	 return: -134.713 	 ep_len: 79.381
# epoch:  26 	 loss: -164.505 	 return: -124.475 	 ep_len: 78.141
# epoch:  27 	 loss: -153.467 	 return: -118.607 	 ep_len: 79.381
# epoch:  28 	 loss: -159.659 	 return: -121.460 	 ep_len: 74.642
# epoch:  29 	 loss: -161.713 	 return: -124.838 	 ep_len: 76.938
# epoch:  30 	 loss: -160.767 	 return: -123.112 	 ep_len: 76.938
# epoch:  31 	 loss: -155.744 	 return: -118.081 	 ep_len: 76.938
# epoch:  32 	 loss: -158.703 	 return: -119.151 	 ep_len: 75.773
# epoch:  33 	 loss: -152.703 	 return: -114.331 	 ep_len: 74.642
# epoch:  34 	 loss: -153.050 	 return: -116.592 	 ep_len: 75.773
# epoch:  35 	 loss: -163.759 	 return: -123.488 	 ep_len: 78.141
# epoch:  36 	 loss: -172.104 	 return: -125.454 	 ep_len: 78.141
# epoch:  37 	 loss: -178.772 	 return: -131.255 	 ep_len: 79.381
# epoch:  38 	 loss: -131.507 	 return: -119.005 	 ep_len: 86.224
# epoch:  39 	 loss: -161.523 	 return: -124.128 	 ep_len: 78.141
# epoch:  40 	 loss: -156.298 	 return: -118.704 	 ep_len: 79.381
# epoch:  41 	 loss: -157.389 	 return: -117.358 	 ep_len: 76.938
# epoch:  42 	 loss: -171.652 	 return: -125.141 	 ep_len: 81.984
# epoch:  43 	 loss: -169.137 	 return: -123.496 	 ep_len: 83.350
# epoch:  44 	 loss: -165.971 	 return: -122.856 	 ep_len: 87.737
# epoch:  45 	 loss: -150.298 	 return: -108.040 	 ep_len: 81.984
# epoch:  46 	 loss: -146.149 	 return: -107.634 	 ep_len: 83.350
# epoch:  47 	 loss: -147.562 	 return: -103.979 	 ep_len: 80.661
# epoch:  48 	 loss: -139.560 	 return: -101.909 	 ep_len: 84.763
# epoch:  49 	 loss: -135.624 	 return: -99.375 	 ep_len: 81.984
# epoch:  50 	 loss: -145.808 	 return: -105.108 	 ep_len: 81.984
# epoch:  51 	 loss: -139.525 	 return: -102.844 	 ep_len: 90.927
# epoch:  52 	 loss: -143.708 	 return: -105.221 	 ep_len: 89.304
# epoch:  53 	 loss: -128.075 	 return: -94.783 	 ep_len: 86.224
# epoch:  54 	 loss: -117.838 	 return: -86.275 	 ep_len: 89.304
# epoch:  55 	 loss: -107.653 	 return: -80.624 	 ep_len: 87.737
# epoch:  56 	 loss: -125.484 	 return: -92.634 	 ep_len: 86.224
# epoch:  57 	 loss: -132.361 	 return: -97.004 	 ep_len: 92.611
# epoch:  58 	 loss: -109.783 	 return: -82.700 	 ep_len: 92.611
# epoch:  59 	 loss: -90.127 	 return: -75.747 	 ep_len: 98.059
# epoch:  60 	 loss: -131.287 	 return: -96.346 	 ep_len: 96.173
# epoch:  61 	 loss: -141.037 	 return: -100.585 	 ep_len: 92.611
# epoch:  62 	 loss: -117.955 	 return: -87.319 	 ep_len: 106.404
# epoch:  63 	 loss: -102.304 	 return: -89.812 	 ep_len: 102.061
# epoch:  64 	 loss: -111.140 	 return: -88.504 	 ep_len: 108.717
# epoch:  65 	 loss: -65.535 	 return: -62.476 	 ep_len: 108.717
# epoch:  66 	 loss: -113.484 	 return: -87.274 	 ep_len: 98.059
# epoch:  67 	 loss: -119.250 	 return: -91.476 	 ep_len: 119.071
# epoch:  68 	 loss: -124.806 	 return: -84.743 	 ep_len: 104.188
# epoch:  69 	 loss: -115.958 	 return: -87.918 	 ep_len: 96.173
# epoch:  70 	 loss: -89.625 	 return: -70.748 	 ep_len: 121.976
# epoch:  71 	 loss: -91.227 	 return: -85.775 	 ep_len: 113.659
# epoch:  72 	 loss: -113.443 	 return: -87.300 	 ep_len: 106.404
# epoch:  73 	 loss: -84.171 	 return: -68.699 	 ep_len: 113.659
# epoch:  74 	 loss: -76.524 	 return: -51.318 	 ep_len: 128.231
# epoch:  75 	 loss: -81.204 	 return: -60.949 	 ep_len: 113.659
# epoch:  76 	 loss: -80.488 	 return: -62.129 	 ep_len: 116.302
# epoch:  77 	 loss: -106.585 	 return: -66.377 	 ep_len: 131.605
# epoch:  78 	 loss: -58.783 	 return: -54.607 	 ep_len: 131.605
# epoch:  79 	 loss: -60.829 	 return: -52.056 	 ep_len: 121.976
# epoch:  80 	 loss: -36.600 	 return: -43.799 	 ep_len: 128.231
# epoch:  81 	 loss: -97.356 	 return: -70.054 	 ep_len: 119.071
# epoch:  82 	 loss: -49.182 	 return: -41.633 	 ep_len: 104.188
# epoch:  83 	 loss: -74.584 	 return: -57.834 	 ep_len: 111.133
# epoch:  84 	 loss: -43.075 	 return: -35.570 	 ep_len: 108.717
# epoch:  85 	 loss: -49.174 	 return: -41.778 	 ep_len: 108.717
# epoch:  86 	 loss: -54.194 	 return: -44.898 	 ep_len: 100.020
# epoch:  87 	 loss: -36.603 	 return: -41.693 	 ep_len: 113.659
# epoch:  88 	 loss: -43.807 	 return: -39.941 	 ep_len: 108.717
# epoch:  89 	 loss: -48.505 	 return: -40.881 	 ep_len: 102.061
# epoch:  90 	 loss: -64.199 	 return: -52.079 	 ep_len: 100.020
# epoch:  91 	 loss: -43.838 	 return: -35.067 	 ep_len: 100.020
# epoch:  92 	 loss: -45.131 	 return: -37.905 	 ep_len: 98.059
# epoch:  93 	 loss: -38.275 	 return: -32.648 	 ep_len: 100.020
# epoch:  94 	 loss: -38.993 	 return: -39.086 	 ep_len: 113.659
# epoch:  95 	 loss: -42.100 	 return: -35.576 	 ep_len: 102.061
# epoch:  96 	 loss: -31.590 	 return: -36.265 	 ep_len: 121.976
# epoch:  97 	 loss: -41.737 	 return: -37.359 	 ep_len: 108.717
# epoch:  98 	 loss: -35.676 	 return: -30.765 	 ep_len: 102.061
# epoch:  99 	 loss: 3.099 	 return: -15.025 	 ep_len: 125.025
# epoch: 100 	 loss: -40.031 	 return: -25.237 	 ep_len: 116.302
# epoch: 101 	 loss: -2.457 	 return: -14.210 	 ep_len: 116.302
# epoch: 102 	 loss: -20.837 	 return: -19.165 	 ep_len: 106.404
# epoch: 103 	 loss: 1.063 	 return: -12.439 	 ep_len: 151.545
# epoch: 104 	 loss: -6.591 	 return: -5.550 	 ep_len: 116.302
# epoch: 105 	 loss: -2.138 	 return: -12.199 	 ep_len: 128.231
# epoch: 106 	 loss: -8.120 	 return: -7.683 	 ep_len: 131.605
# epoch: 107 	 loss: -34.371 	 return: -16.089 	 ep_len: 156.281
# epoch: 108 	 loss: -25.102 	 return: -15.514 	 ep_len: 151.545
# epoch: 109 	 loss: 26.605 	 return: 6.016 	 ep_len: 185.222
# epoch: 110 	 loss: 0.468 	 return: -5.505 	 ep_len: 178.607
# epoch: 111 	 loss: 6.458 	 return: -5.014 	 ep_len: 200.040
# epoch: 112 	 loss: 43.145 	 return: 13.045 	 ep_len: 208.375
# epoch: 113 	 loss: 34.548 	 return: 7.436 	 ep_len: 172.448
# epoch: 114 	 loss: 12.279 	 return: -6.084 	 ep_len: 178.607
# epoch: 115 	 loss: 2.646 	 return: -4.751 	 ep_len: 185.222
# epoch: 116 	 loss: 36.222 	 return: 20.634 	 ep_len: 178.607
# epoch: 117 	 loss: 34.853 	 return: 11.931 	 ep_len: 217.435
# epoch: 118 	 loss: 30.677 	 return: 8.017 	 ep_len: 238.143
# epoch: 119 	 loss: 22.429 	 return: 4.460 	 ep_len: 250.050
# epoch: 120 	 loss: 31.187 	 return: 13.214 	 ep_len: 277.833
# epoch: 121 	 loss: 77.356 	 return: 37.560 	 ep_len: 312.562
# epoch: 122 	 loss: 24.082 	 return: 3.089 	 ep_len: 250.050
# epoch: 123 	 loss: 56.530 	 return: 32.528 	 ep_len: 357.214
# epoch: 124 	 loss: 35.312 	 return: 15.610 	 ep_len: 250.050
# epoch: 125 	 loss: 75.949 	 return: 37.961 	 ep_len: 294.176
# epoch: 126 	 loss: 22.887 	 return: 18.219 	 ep_len: 333.400
# epoch: 127 	 loss: 53.963 	 return: 34.165 	 ep_len: 312.562
# epoch: 128 	 loss: -51.561 	 return: -30.033 	 ep_len: 250.050
# epoch: 129 	 loss: 55.092 	 return: 38.034 	 ep_len: 357.214
# epoch: 130 	 loss: 57.967 	 return: 42.964 	 ep_len: 384.692
# epoch: 131 	 loss: 78.910 	 return: 44.535 	 ep_len: 263.211
# epoch: 132 	 loss: 38.769 	 return: 33.719 	 ep_len: 357.214
# epoch: 133 	 loss: 63.035 	 return: 46.050 	 ep_len: 294.176
# epoch: 134 	 loss: 29.734 	 return: 15.692 	 ep_len: 312.562
# epoch: 135 	 loss: 28.852 	 return: 14.656 	 ep_len: 294.176
# epoch: 136 	 loss: 77.542 	 return: 54.319 	 ep_len: 312.562
# epoch: 137 	 loss: 44.404 	 return: 21.156 	 ep_len: 185.222
# epoch: 138 	 loss: 57.700 	 return: 41.017 	 ep_len: 208.375
# epoch: 139 	 loss: 77.952 	 return: 42.996 	 ep_len: 312.562
# epoch: 140 	 loss: 57.116 	 return: 32.426 	 ep_len: 277.833
# epoch: 141 	 loss: 57.443 	 return: 37.277 	 ep_len: 250.050
# epoch: 142 	 loss: 90.383 	 return: 60.906 	 ep_len: 357.214
# epoch: 143 	 loss: 41.476 	 return: 29.463 	 ep_len: 312.562
# epoch: 144 	 loss: 71.241 	 return: 34.696 	 ep_len: 263.211
# epoch: 145 	 loss: 70.291 	 return: 45.406 	 ep_len: 294.176
# epoch: 146 	 loss: 33.686 	 return: 18.312 	 ep_len: 312.562
# epoch: 147 	 loss: 74.333 	 return: 34.487 	 ep_len: 294.176
# epoch: 148 	 loss: 65.874 	 return: 42.837 	 ep_len: 312.562
# epoch: 149 	 loss: 77.670 	 return: 59.748 	 ep_len: 416.750
# epoch: 150 	 loss: 24.876 	 return: 12.477 	 ep_len: 357.214
# epoch: 151 	 loss: 29.371 	 return: 20.438 	 ep_len: 357.214
# epoch: 152 	 loss: 57.126 	 return: 31.098 	 ep_len: 384.692
# epoch: 153 	 loss: 77.099 	 return: 59.189 	 ep_len: 416.750
# epoch: 154 	 loss: 60.721 	 return: 51.160 	 ep_len: 384.692
# epoch: 155 	 loss: 74.451 	 return: 49.162 	 ep_len: 384.692
# epoch: 156 	 loss: 58.083 	 return: 50.326 	 ep_len: 454.636
# epoch: 157 	 loss: 58.488 	 return: 43.711 	 ep_len: 416.750
# epoch: 158 	 loss: 51.310 	 return: 45.041 	 ep_len: 454.636
# epoch: 159 	 loss: 51.702 	 return: 46.421 	 ep_len: 454.636
# epoch: 160 	 loss: 63.460 	 return: 55.425 	 ep_len: 454.636
# epoch: 161 	 loss: 38.988 	 return: 27.260 	 ep_len: 454.636
# epoch: 162 	 loss: 36.672 	 return: 31.727 	 ep_len: 454.636
# epoch: 163 	 loss: 14.336 	 return: 4.170 	 ep_len: 454.636
# epoch: 164 	 loss: 63.154 	 return: 54.559 	 ep_len: 454.636
# epoch: 165 	 loss: 69.290 	 return: 58.680 	 ep_len: 454.636
# epoch: 166 	 loss: 38.372 	 return: 22.675 	 ep_len: 384.692
# epoch: 167 	 loss: 20.096 	 return: 10.645 	 ep_len: 384.692
# epoch: 168 	 loss: 50.444 	 return: 33.171 	 ep_len: 312.562
# epoch: 169 	 loss: 10.658 	 return: 2.657 	 ep_len: 312.562
# epoch: 170 	 loss: 94.852 	 return: 74.964 	 ep_len: 416.750
# epoch: 171 	 loss: 75.984 	 return: 59.134 	 ep_len: 357.214
# epoch: 172 	 loss: 107.987 	 return: 84.803 	 ep_len: 384.692
# epoch: 173 	 loss: 89.085 	 return: 67.133 	 ep_len: 357.214
# epoch: 174 	 loss: 45.676 	 return: 32.202 	 ep_len: 312.562
# epoch: 175 	 loss: 62.936 	 return: 43.074 	 ep_len: 294.176
# epoch: 176 	 loss: 83.965 	 return: 50.623 	 ep_len: 294.176
# epoch: 177 	 loss: 54.676 	 return: 37.526 	 ep_len: 227.318
# epoch: 178 	 loss: 57.256 	 return: 36.751 	 ep_len: 277.833
# epoch: 179 	 loss: 72.781 	 return: 56.856 	 ep_len: 312.562
# epoch: 180 	 loss: 45.629 	 return: 34.910 	 ep_len: 277.833
# epoch: 181 	 loss: 16.739 	 return: 14.512 	 ep_len: 250.050
# epoch: 182 	 loss: 31.441 	 return: 21.819 	 ep_len: 217.435
# epoch: 183 	 loss: 68.686 	 return: 45.463 	 ep_len: 250.050
# epoch: 184 	 loss: 10.234 	 return: 8.039 	 ep_len: 227.318
# epoch: 185 	 loss: 62.417 	 return: 41.312 	 ep_len: 238.143
# epoch: 186 	 loss: 30.515 	 return: 21.588 	 ep_len: 166.700
# epoch: 187 	 loss: 66.719 	 return: 48.212 	 ep_len: 250.050
# epoch: 188 	 loss: 14.767 	 return: 16.978 	 ep_len: 200.040
# epoch: 189 	 loss: 67.229 	 return: 45.516 	 ep_len: 217.435
# epoch: 190 	 loss: 60.903 	 return: 35.512 	 ep_len: 250.050
# epoch: 191 	 loss: 42.805 	 return: 24.684 	 ep_len: 217.435
# epoch: 192 	 loss: 47.282 	 return: 38.856 	 ep_len: 227.318
# epoch: 193 	 loss: 61.667 	 return: 41.976 	 ep_len: 217.435
# epoch: 194 	 loss: 35.144 	 return: 32.935 	 ep_len: 192.346
# epoch: 195 	 loss: 71.749 	 return: 54.286 	 ep_len: 238.143
# epoch: 196 	 loss: 44.588 	 return: 39.225 	 ep_len: 277.833
# epoch: 197 	 loss: 63.756 	 return: 63.682 	 ep_len: 333.400
# epoch: 198 	 loss: 58.420 	 return: 61.154 	 ep_len: 312.562
# epoch: 199 	 loss: 34.585 	 return: 33.649 	 ep_len: 384.692
# epoch: 200 	 loss: 106.230 	 return: 119.138 	 ep_len: 454.636
# epoch: 201 	 loss: 32.066 	 return: 19.647 	 ep_len: 416.750
# epoch: 202 	 loss: 54.474 	 return: 47.953 	 ep_len: 416.750
# epoch: 203 	 loss: 83.819 	 return: 66.521 	 ep_len: 416.750
# epoch: 204 	 loss: 75.804 	 return: 68.378 	 ep_len: 454.636
# epoch: 205 	 loss: 76.793 	 return: 61.972 	 ep_len: 416.750
# epoch: 206 	 loss: 60.737 	 return: 46.879 	 ep_len: 416.750
# epoch: 207 	 loss: 76.997 	 return: 66.991 	 ep_len: 454.636
# epoch: 208 	 loss: 82.988 	 return: 68.918 	 ep_len: 454.636
# epoch: 209 	 loss: 95.700 	 return: 84.577 	 ep_len: 454.636
# epoch: 210 	 loss: 92.781 	 return: 86.815 	 ep_len: 454.636
# epoch: 211 	 loss: 76.678 	 return: 65.735 	 ep_len: 454.636
# epoch: 212 	 loss: 88.824 	 return: 83.080 	 ep_len: 454.636
# epoch: 213 	 loss: 84.480 	 return: 67.226 	 ep_len: 416.750
# epoch: 214 	 loss: 83.590 	 return: 71.608 	 ep_len: 454.636
# epoch: 215 	 loss: 50.085 	 return: 50.343 	 ep_len: 454.636
# epoch: 216 	 loss: 92.064 	 return: 86.403 	 ep_len: 454.636
# epoch: 217 	 loss: 89.146 	 return: 80.593 	 ep_len: 454.636
# epoch: 218 	 loss: 80.100 	 return: 72.321 	 ep_len: 454.636
# epoch: 219 	 loss: 91.371 	 return: 79.411 	 ep_len: 454.636
# epoch: 220 	 loss: 68.160 	 return: 59.262 	 ep_len: 454.636
# epoch: 221 	 loss: 71.294 	 return: 60.984 	 ep_len: 454.636
# epoch: 222 	 loss: 80.019 	 return: 74.248 	 ep_len: 454.636
# epoch: 223 	 loss: 75.748 	 return: 65.352 	 ep_len: 454.636
# epoch: 224 	 loss: 70.496 	 return: 60.849 	 ep_len: 454.636
# epoch: 225 	 loss: 58.257 	 return: 51.720 	 ep_len: 454.636
# epoch: 226 	 loss: 49.547 	 return: 47.380 	 ep_len: 454.636
# epoch: 227 	 loss: 84.969 	 return: 73.104 	 ep_len: 454.636
# epoch: 228 	 loss: 89.850 	 return: 78.489 	 ep_len: 454.636
# epoch: 229 	 loss: 90.947 	 return: 77.547 	 ep_len: 454.636
# epoch: 230 	 loss: 92.278 	 return: 80.987 	 ep_len: 454.636
# epoch: 231 	 loss: 94.757 	 return: 81.901 	 ep_len: 454.636
# epoch: 232 	 loss: 74.525 	 return: 63.522 	 ep_len: 454.636
# epoch: 233 	 loss: 85.440 	 return: 76.342 	 ep_len: 454.636
# epoch: 234 	 loss: 85.096 	 return: 71.093 	 ep_len: 454.636
# epoch: 235 	 loss: 91.221 	 return: 78.863 	 ep_len: 454.636
# epoch: 236 	 loss: 83.110 	 return: 70.665 	 ep_len: 454.636
# epoch: 237 	 loss: 94.714 	 return: 84.925 	 ep_len: 454.636
# epoch: 238 	 loss: 99.465 	 return: 88.606 	 ep_len: 454.636
# epoch: 239 	 loss: 108.858 	 return: 92.892 	 ep_len: 454.636
# epoch: 240 	 loss: 71.471 	 return: 62.717 	 ep_len: 454.636
# epoch: 241 	 loss: 92.834 	 return: 78.367 	 ep_len: 454.636
# epoch: 242 	 loss: 82.454 	 return: 70.412 	 ep_len: 454.636
# epoch: 243 	 loss: 103.642 	 return: 87.501 	 ep_len: 416.750
# epoch: 244 	 loss: 46.472 	 return: 44.864 	 ep_len: 416.750
# epoch: 245 	 loss: 102.725 	 return: 92.741 	 ep_len: 454.636
# epoch: 246 	 loss: 96.492 	 return: 84.487 	 ep_len: 416.750
# epoch: 247 	 loss: 90.359 	 return: 71.291 	 ep_len: 357.214
# epoch: 248 	 loss: 100.888 	 return: 80.711 	 ep_len: 416.750
# epoch: 249 	 loss: 99.088 	 return: 92.624 	 ep_len: 454.636
# epoch: 250 	 loss: 54.448 	 return: 49.599 	 ep_len: 416.750
# epoch: 251 	 loss: 92.492 	 return: 81.465 	 ep_len: 454.636
# epoch: 252 	 loss: 92.412 	 return: 80.949 	 ep_len: 416.750
# epoch: 253 	 loss: 86.421 	 return: 79.699 	 ep_len: 416.750
# epoch: 254 	 loss: 99.265 	 return: 96.372 	 ep_len: 454.636
# epoch: 255 	 loss: 97.304 	 return: 93.753 	 ep_len: 416.750
# epoch: 256 	 loss: 89.357 	 return: 86.494 	 ep_len: 454.636
# epoch: 257 	 loss: 81.423 	 return: 77.678 	 ep_len: 416.750
# epoch: 258 	 loss: 80.351 	 return: 66.195 	 ep_len: 416.750
# epoch: 259 	 loss: 94.306 	 return: 78.112 	 ep_len: 416.750
# epoch: 260 	 loss: 83.901 	 return: 71.299 	 ep_len: 454.636
# epoch: 261 	 loss: 88.511 	 return: 91.353 	 ep_len: 357.214
# epoch: 262 	 loss: 77.152 	 return: 64.609 	 ep_len: 357.214
# epoch: 263 	 loss: 66.982 	 return: 51.530 	 ep_len: 312.562
# epoch: 264 	 loss: 63.077 	 return: 58.381 	 ep_len: 357.214
# epoch: 265 	 loss: 77.138 	 return: 75.959 	 ep_len: 312.562
# epoch: 266 	 loss: 75.144 	 return: 78.697 	 ep_len: 384.692
# epoch: 267 	 loss: 81.662 	 return: 82.705 	 ep_len: 357.214
# epoch: 268 	 loss: 65.793 	 return: 55.571 	 ep_len: 357.214
# epoch: 269 	 loss: 81.816 	 return: 92.922 	 ep_len: 384.692
# epoch: 270 	 loss: 65.202 	 return: 80.226 	 ep_len: 384.692
# epoch: 271 	 loss: 53.764 	 return: 58.999 	 ep_len: 416.750
# epoch: 272 	 loss: 63.596 	 return: 66.331 	 ep_len: 384.692
# epoch: 273 	 loss: 71.947 	 return: 78.864 	 ep_len: 416.750
# epoch: 274 	 loss: 82.923 	 return: 97.158 	 ep_len: 454.636
# epoch: 275 	 loss: 29.999 	 return: 33.426 	 ep_len: 416.750
# epoch: 276 	 loss: 48.003 	 return: 42.588 	 ep_len: 357.214
# epoch: 277 	 loss: 72.655 	 return: 67.916 	 ep_len: 416.750
# epoch: 278 	 loss: 59.317 	 return: 65.731 	 ep_len: 416.750
# epoch: 279 	 loss: 56.379 	 return: 50.069 	 ep_len: 454.636
# epoch: 280 	 loss: 71.090 	 return: 84.737 	 ep_len: 454.636
# epoch: 281 	 loss: 73.809 	 return: 70.093 	 ep_len: 454.636
# epoch: 282 	 loss: 80.849 	 return: 75.665 	 ep_len: 454.636
# epoch: 283 	 loss: 71.214 	 return: 66.619 	 ep_len: 454.636
# epoch: 284 	 loss: 65.473 	 return: 61.396 	 ep_len: 454.636
# epoch: 285 	 loss: 52.845 	 return: 52.007 	 ep_len: 454.636
# epoch: 286 	 loss: 43.226 	 return: 39.197 	 ep_len: 454.636
# epoch: 287 	 loss: 52.371 	 return: 46.252 	 ep_len: 454.636
# epoch: 288 	 loss: 55.543 	 return: 51.320 	 ep_len: 454.636
# epoch: 289 	 loss: 60.875 	 return: 56.105 	 ep_len: 454.636
# epoch: 290 	 loss: 68.528 	 return: 63.534 	 ep_len: 454.636
# epoch: 291 	 loss: 65.843 	 return: 60.412 	 ep_len: 454.636
# epoch: 292 	 loss: 60.798 	 return: 55.461 	 ep_len: 454.636
# epoch: 293 	 loss: 55.818 	 return: 53.263 	 ep_len: 454.636
# epoch: 294 	 loss: 51.421 	 return: 46.743 	 ep_len: 454.636
# epoch: 295 	 loss: 60.419 	 return: 55.776 	 ep_len: 454.636
# epoch: 296 	 loss: 54.856 	 return: 50.443 	 ep_len: 454.636
# epoch: 297 	 loss: 63.640 	 return: 58.967 	 ep_len: 454.636
# epoch: 298 	 loss: 55.854 	 return: 51.172 	 ep_len: 454.636
# epoch: 299 	 loss: 58.087 	 return: 52.596 	 ep_len: 454.636

# %%
#@title Visualize trained policy
trained.eval()
# Out:
# return = 61.75149101160204. episode length = 502

# %%
dir()
# Out:
# ['Adam',
#  'Box',
#  'Categorical',
#  'Discrete',
#  'In',
#  'Out',
#  'PolicyGradientTrainer',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'display',
#  'exit',
#  'get_ipython',
#  'gym',
#  'mlp',
#  'nn',
#  'np',
#  'pd',
#  'plt',
#  'quit',
#  'random',
#  'sns',
#  'stats',
#  'torch',
#  'trained',
#  'untrained']

# %%
#@title Plot episode returns per epoch.
_ = sns.lineplot(data=stats, x="iteration", y="episode_returns")

# %%
#@title Plot episode lengths per epoch.
_ = sns.lineplot(data=stats, x="iteration", y="episode_lens")
